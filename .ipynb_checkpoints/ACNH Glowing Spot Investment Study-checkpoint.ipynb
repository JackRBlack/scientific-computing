# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
def expectation(x, alpha):
    return (3*alpha - 1)*x + 30000 * (1-alpha)

# %%
def expectation_2(x, beta):
    alpha = beta * (99000 - x) / 89000
    return (3*alpha - 1)*x + 30000 * (1-alpha)

# %%
x1 = np.linspace(0, 10000, 10001)
x2 = np.linspace(10001, 99000, 89000)

# %%
alpha = 0.3
E1 = 2 * x1
E2 = expectation(x2, alpha)

# %%
def demo(alpha):
    E1 = 2 * x1
    E2 = expectation(x2, alpha)
    plt.figure(figsize=(5, 2), dpi=200)
    plt.plot(x1, E1, c='k')
    plt.plot(x2, E2, c='k')
    plt.xlabel('Buried Bells')
    plt.ylabel('Expectation')
    plt.show()
    return

# %%
interact(demo, alpha=(0, 1, 0.1));
# Out:
# interactive(children=(FloatSlider(value=0.0, description='alpha', max=1.0), Output()), _dom_classes=('widget-i…

# %%
def demo_2(beta):
    E1 = 2 * x1
    E2 = expectation_2(x2, beta)
    plt.figure(figsize=(5, 2), dpi=200)
    plt.plot(x1, E1, c='k')
    plt.plot(x2, E2, c='k')
    plt.xlabel('Buried Bells')
    plt.ylabel('Expectation')
    plt.show()
    return

# %%
demo_2(1)
