# %%
import numpy as np
from matplotlib import pyplot as plt
import time
from multiprocessing import Pool

# %%
def g_feedback(y_feedback):
    '''
        Feedback function.
    '''
    return 1/(1+y_feedback**4)

# %%
def recurrence_relation(y_feedback, B, A, freq, tau):
    '''
        Recurrence relation for feedback amplitude.
    '''
    y_feedback_new = np.exp(-1 / freq / tau) * (B * A * g_feedback(y_feedback) + y_feedback)
    return y_feedback_new

# %%
recurrence_relation(0.8, 10, 0.8, 10, 0.1)
# Out:
# 2.3821550919351235

# %%
B = 1
A = 30
freq = 10
tau = 0.1

y_series = []
y_series.append(0)

for i in range(100):
    y_series.append(recurrence_relation(y_series[-1], B, A, freq, tau))
    
#x_series_lim_4 = np.around(x_series[-100:], 4)
#np.unique(x_series_lim_4)

# %%
y_series
# Out:
# [0,
#  11.03638323514327,
#  4.06080235573343,
#  1.534323283018986,
#  2.2514472351993593,
#  1.2416876586380499,
#  3.7247867858788415,
#  1.4273113280228251,
#  2.667959151186378,
#  1.19509745448436,
#  4.070135706044013,
#  1.5373885321086163,
#  2.241197483882218,
#  1.245241666907659,
#  3.699857184783387,
#  1.4196849132950886,
#  2.702401951186355,
#  1.1972812529826906,
#  4.053170847445358,
#  1.5318200931967065,
#  2.259881435793708,
#  1.238879647909077,
#  3.7446238098810216,
#  1.4334159532956037,
#  2.640879434792498,
#  1.1938533127630098,
#  4.079835286617016,
#  1.540578480710758,
#  2.230621582563621,
#  1.2490754537400746,
#  3.6731867119329653,
#  1.4115840839981164,
#  2.739743918263149,
#  1.2003581033006927,
#  4.029398973240569,
#  1.5240412295674266,
#  2.2864619546621485,
#  1.2306934930405156,
#  3.803163786585264,
#  1.4516077521763484,
#  2.562709636433413,
#  1.1928459698604437,
#  4.087707066860118,
#  1.5431705821020552,
#  2.22209551311579,
#  1.252292398854912,
#  3.650984319442608,
#  1.404888076003279,
#  2.771207639825688,
#  1.2034832451122466,
#  4.00541029713404,
#  1.5162205717775523,
#  2.313758701580992,
#  1.223284043576321,
#  3.85706472658208,
#  1.4685758965136861,
#  2.493110137594647,
#  1.1956238164024933,
#  4.06603961211524,
#  1.5360427798789016,
#  2.2456869139920532,
#  1.2436656640872357,
#  3.71088762680559,
#  1.4230529760790698,
#  2.6871064358876358,
#  1.196231062322126,
#  4.061319648022837,
#  1.5344930613684866,
#  2.250877272279952,
#  1.2418811807025887,
#  3.72342422470642,
#  1.4268931751233884,
#  2.669829923572577,
#  1.1951991326703924,
#  4.069344108073315,
#  1.5371283935260223,
#  2.242064019045743,
#  1.2449351070938028,
#  3.7019997492746057,
#  1.4203383311703885,
#  2.699424057911234,
#  1.197066944331701,
#  4.054832297543037,
#  1.532364818294858,
#  2.2580411394270015,
#  1.2394834930142138,
#  3.7403475173630114,
#  1.43209732246231,
#  2.6466922000239417,
#  1.1940838735087786,
#  4.07803589982818,
#  1.5399863698607705,
#  2.2325776868067666,
#  1.2483534047779945,
#  3.6781922382196806,
#  1.4130997540067085,
#  2.732697361077224,
#  1.199723548317201,
#  4.034289067851169,
#  1.5256390979255685,
#  2.2809559345071535]

# %%
def bifurcation_map_attractor(B, A, freq, tau, N = 5000):
    x_series = []
    x_series.append(0)

    for i in range(N):
        x_series.append(recurrence_relation(x_series[-1], B, A, freq, tau))

    x_series_lim_4 = np.around(x_series[-100:], 4)
    return np.unique(x_series_lim_4)

# %%
B = 1
A = 30
freq = 10
tau = 0.1

# %%
bifurcation_map_attractor(B, 10, freq, tau, N = 5000)
# Out:
# array([0.9728, 2.2985])

# %%
B = 1
A = 30
freq = 10
tau = 0.1

A = np.linspace(0, 30, 200)

series_limits = []

for a in A:
    series_limits.append(bifurcation_map_attractor(B, a, freq, tau, N = 20000))

# %%
plt.figure(figsize=(6, 4), dpi=200)
for i in range(len(A)):
    for lim in series_limits[i]:
        plt.plot(A[i], lim, '.', c='k', markersize=1)
plt.xlabel('A')
plt.ylabel('$\lim_{n \\rightarrow \infty}~y_n$')
plt.show()

# %%
def bifurcation_map_lim_point_contrast(B, A, freq, tau, N = 20000):
    x_series_lim_unique = bifurcation_map_attractor(B, A, freq, tau, N = 20000)
    lim_point = np.zeros([2, len(x_series_lim_unique)])
    lim_point[0] = A * np.ones(len(x_series_lim_unique))
    lim_point[1] = x_series_lim_unique
    return lim_point

# %%
bifurcation_map_lim_point(B, 20, freq, tau)
# Out:
# array([[20.    , 20.    , 20.    , 20.    ],
#        [ 1.098 ,  1.3064,  2.3612,  3.403 ]])

# %%
def bifurcation_map_lim_point_contrast_child(a, B = 1, freq = 10, tau = 0.1, N = 20000):
    lim_points = np.array([[], []])
    for A in a:
        lim_points = np.concatenate((lim_points, bifurcation_map_lim_point_contrast(B, A, freq, tau, N)), axis=1)
    return lim_points

# %%
a = np.linspace(0, 100, 800)
a_split = np.split(a, 4)

# create threads (out side of the loop to prevent memory leak)
pool = Pool(processes = 4)

# set timer
start_time = time.time()

# calculate
results = pool.map(bifurcation_map_lim_point_contrast_child, a_split)

# close threads
pool.close()

# processing results
lim_points = np.array([[], []])
for result in results:
    lim_points = np.concatenate((lim_points, result), axis=1)

# print elapsed time
elapsed_time = time.time() - start_time
print("Time consuming: {0:.3f}s.".format(elapsed_time))
# Out:
# Time consuming: 9.380s.

# %%
plt.figure(figsize=(6, 4), dpi=200)
plt.rcParams.update({'font.size': 8})
plt.scatter(lim_points[0], lim_points[1], c='#311B92', s = 0.5, marker = '.', alpha = 1, linewidths = 0)
plt.xlabel('A or contrast')
plt.ylabel('$\lim_{n \\rightarrow \infty}~y_n$')
plt.title('bifurcation map for $y_{n}$ ($B = 1,~f=10,~\\tau=0.1$)')
#plt.savefig('./test.png', dpi = 200, format = 'png')
plt.show()

# %%
lim_points = lim_point_y2x_contrast(lim_points)
plt.figure(figsize=(6, 4), dpi=200)
plt.rcParams.update({'font.size': 8})
plt.scatter(lim_points[0], lim_points[1], c='#311B92', s = 0.5, marker = '.', alpha = 1, linewidths = 0)
plt.xlabel('A or contrast')
plt.ylabel('$\lim_{n \\rightarrow \infty}~x_n$')
plt.title('bifurcation map for $x_{n}$ ($B = 1,~f=10,~\\tau=0.1$)')
#plt.savefig('./test.png', dpi = 200, format = 'png')
plt.show()

# %%
def bifurcation_map_lim_point_frequency(B, A, freq, tau, N = 20000):
    x_series_lim_unique = bifurcation_map_attractor(B, A, freq, tau, N = 20000)
    lim_point = np.zeros([2, len(x_series_lim_unique)])
    lim_point[0] = freq * np.ones(len(x_series_lim_unique))
    lim_point[1] = x_series_lim_unique
    return lim_point

# %%
def bifurcation_map_lim_point_frequency_child(f, A = 10, B = 1, tau = 0.1, N = 20000):
    lim_points = np.array([[], []])
    for freq in f:
        lim_points = np.concatenate((lim_points, bifurcation_map_lim_point_frequency(B, A, freq, tau, N)), axis=1)
    return lim_points

# %%
f = np.linspace(1, 30, 100)
f_split = np.split(f, 4)

# create threads (out side of the loop to prevent memory leak)
pool = Pool(processes = 4)

# set timer
start_time = time.time()

# calculate
results = pool.map(bifurcation_map_lim_point_frequency_child, f_split)

# close threads
pool.close()

# processing results
lim_points = np.array([[], []])
for result in results:
    lim_points = np.concatenate((lim_points, result), axis=1)

# print elapsed time
elapsed_time = time.time() - start_time
print("Time consuming: {0:.3f}s.".format(elapsed_time))
# Out:
# Time consuming: 1.617s.

# %%
plt.figure(figsize=(6, 4), dpi=200)
plt.rcParams.update({'font.size': 8})
plt.scatter(lim_points[0], lim_points[1], c='#311B92', s = 2, marker = '.', alpha = 1, linewidths = 0)
plt.xlabel('$f$ or frequency')
plt.ylabel('$\lim_{n \\rightarrow \infty}~y_n$')
plt.title('bifurcation map for $y_{n}$ ($B = 1,~A=10,~\\tau=0.1$)')
#plt.savefig('./test.png', dpi = 200, format = 'png')
plt.show()

# %%
def bifurcation_map_lim_point_frequency_child(f, A = 20, B = 1, tau = 0.1, N = 20000):
    lim_points = np.array([[], []])
    for freq in f:
        lim_points = np.concatenate((lim_points, bifurcation_map_lim_point_frequency(B, A, freq, tau, N)), axis=1)
    return lim_points

# %%
f = np.linspace(1, 30, 100)
f_split = np.split(f, 4)

# create threads (out side of the loop to prevent memory leak)
pool = Pool(processes = 4)

# set timer
start_time = time.time()

# calculate
results = pool.map(bifurcation_map_lim_point_frequency_child, f_split)

# close threads
pool.close()

# processing results
lim_points = np.array([[], []])
for result in results:
    lim_points = np.concatenate((lim_points, result), axis=1)

# print elapsed time
elapsed_time = time.time() - start_time
print("Time consuming: {0:.3f}s.".format(elapsed_time))
# Out:
# Time consuming: 1.531s.

# %%
plt.figure(figsize=(6, 4), dpi=200)
plt.rcParams.update({'font.size': 8})
plt.scatter(lim_points[0], lim_points[1], c='#311B92', s = 2, marker = '.', alpha = 1, linewidths = 0)
plt.xlabel('$f$ or frequency')
plt.ylabel('$\lim_{n \\rightarrow \infty}~y_n$')
plt.title('bifurcation map for $y_{n}$ ($B = 1,~A=20,~\\tau=0.1$)')
#plt.savefig('./test.png', dpi = 200, format = 'png')
plt.show()

# %%
def bifurcation_map_lim_point_frequency_child(f, A = 26, B = 1, tau = 0.1, N = 20000):
    lim_points = np.array([[], []])
    for freq in f:
        lim_points = np.concatenate((lim_points, bifurcation_map_lim_point_frequency(B, A, freq, tau, N)), axis=1)
    return lim_points

# %%
f = np.linspace(1, 30, 800)
f_split = np.split(f, 4)

# create threads (out side of the loop to prevent memory leak)
pool = Pool(processes = 4)

# set timer
start_time = time.time()

# calculate
results = pool.map(bifurcation_map_lim_point_frequency_child, f_split)

# close threads
pool.close()

# processing results
lim_points = np.array([[], []])
for result in results:
    lim_points = np.concatenate((lim_points, result), axis=1)

# print elapsed time
elapsed_time = time.time() - start_time
print("Time consuming: {0:.3f}s.".format(elapsed_time))
# Out:
# Time consuming: 11.625s.

# %%
plt.figure(figsize=(6, 4), dpi=200)
plt.rcParams.update({'font.size': 8})
plt.scatter(lim_points[0], lim_points[1], c='#311B92', s = 1, marker = '.', alpha = 1, linewidths = 0)
plt.xlabel('$f$ or frequency')
plt.ylabel('$\lim_{n \\rightarrow \infty}~y_n$')
plt.title('bifurcation map for $y_{n}$ ($B = 1,~A=26,~\\tau=0.1$)')
#plt.savefig('./test.png', dpi = 200, format = 'png')
plt.show()

# %%
def bifurcation_map_lim_point_frequency_child(f, A = 40, B = 1, tau = 0.1, N = 20000):
    lim_points = np.array([[], []])
    for freq in f:
        lim_points = np.concatenate((lim_points, bifurcation_map_lim_point_frequency(B, A, freq, tau, N)), axis=1)
    return lim_points

# %%
f = np.linspace(1, 30, 800)
f_split = np.split(f, 4)

# create threads (out side of the loop to prevent memory leak)
pool = Pool(processes = 4)

# set timer
start_time = time.time()

# calculate
results = pool.map(bifurcation_map_lim_point_frequency_child, f_split)

# close threads
pool.close()

# processing results
lim_points = np.array([[], []])
for result in results:
    lim_points = np.concatenate((lim_points, result), axis=1)

# print elapsed time
elapsed_time = time.time() - start_time
print("Time consuming: {0:.3f}s.".format(elapsed_time))
# Out:
# Time consuming: 10.971s.

# %%
plt.figure(figsize=(6, 4), dpi=200)
plt.rcParams.update({'font.size': 8})
plt.scatter(lim_points[0], lim_points[1], c='#311B92', s = 1, marker = '.', alpha = 1, linewidths = 0)
plt.xlabel('$f$ or frequency')
plt.ylabel('$\lim_{n \\rightarrow \infty}~y_n$')
plt.title('bifurcation map for $y_{n}$ ($B = 1,~A=40,~\\tau=0.1$)')
#plt.savefig('./test.png', dpi = 200, format = 'png')
plt.show()

# %%
lim_points[1]
# Out:
# array([1.2000e-03, 1.7000e-03, 2.3000e-03, ..., 2.2919e+00, 2.2926e+00,
#        2.2933e+00])

# %%
def y2x(y_feedback, A):
    return A * g_feedback(y_feedback)

# %%
def lim_point_y2x_contrast(lim_point):
    lim_point_new = lim_point.copy()
    for i in range(len(lim_point_new[0])):
        lim_point_new[1][i] = y2x(lim_point_new[1][i], lim_point_new[0][i])
    return lim_point_new

# %%
def lim_point_y2x_frequency(lim_point, A):
    lim_point_new = lim_point.copy()
    for i in range(len(lim_point_new[0])):
        lim_point_new[1][i] = y2x(lim_point_new[1][i], A)
    return lim_point_new

# %%
A = 40

def bifurcation_map_lim_point_frequency_child(f, A = 40, B = 1, tau = 0.1, N = 20000):
    lim_points = np.array([[], []])
    for freq in f:
        lim_points = np.concatenate((lim_points, bifurcation_map_lim_point_frequency(B, A, freq, tau, N)), axis=1)
    return lim_points

f = np.linspace(1, 30, 800)
f_split = np.split(f, 4)

# create threads (out side of the loop to prevent memory leak)
pool = Pool(processes = 4)

# set timer
start_time = time.time()

# calculate
results = pool.map(bifurcation_map_lim_point_frequency_child, f_split)

# close threads
pool.close()

# processing results
lim_points = np.array([[], []])
for result in results:
    lim_points = np.concatenate((lim_points, result), axis=1)

# print elapsed time
elapsed_time = time.time() - start_time
print("Time consuming: {0:.3f}s.".format(elapsed_time))

lim_points = lim_point_y2x_frequency(lim_points, A)
# Out:
# Time consuming: 12.479s.

# %%
plt.figure(figsize=(6, 4), dpi=200)
plt.rcParams.update({'font.size': 8})
plt.scatter(lim_points[0], lim_points[1], c='#311B92', s = 1, marker = '.', alpha = 1, linewidths = 0)
plt.xlabel('$f$ or frequency')
plt.ylabel('$\lim_{n \\rightarrow \infty}~x_n$')
plt.title('bifurcation map for $x_{n}$ ($B = 1,~A=40,~\\tau=0.1$)')
#plt.savefig('./test.png', dpi = 200, format = 'png')
plt.show()
