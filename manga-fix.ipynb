# %% [markdown]
# # Manga Fix

# %%
import numpy as np
from PIL import Image
import imageio
from matplotlib import pyplot as plt

# %%
im = np.array(Image.open('./mii-chan.png').convert('L'))

# %%
im.shape
# Out:
# (542, 962)

# %%
plt.imshow(im, cmap='gray')

# %%
divider = 120

im_test = im.copy()
im_test[im_test <= divider] = 0
im_test[im_test > divider] = 255
plt.imshow(im_test, cmap='gray')
